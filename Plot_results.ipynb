# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
from matplotlib import pyplot as plt

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Best Results.xlsx',
#  'charles',
#  'CIFO_Agottani.docx',
#  'CIFO_Agottani.pdf',
#  'data',
#  'int_bin.py',
#  'ks.py',
#  'Plot_results.ipynb',
#  's100_hill_climp_tournament_pmx_co_inversion_mutation',
#  's100_random_tournament_cycle_co_inversion_mutation',
#  's100_random_tournament_pmx_co_inversion_mutation',
#  's100_random_tournament_pmx_co_inversion_mutation_EF',
#  's100_random_tournament_pmx_co_inversion_mutation_pr',
#  's100_random_tournament_pmx_co_inversion_mutation_uy',
#  's100_random_tournament_pmx_co_swap_mutation',
#  's100_sim_annealing_tournament_pmx_co_inversion_mutation',
#  's50_random_tournament_pmx_co_inversion_mutation',
#  'tsp.py',
#  'tsp_pr.py',
#  'tsp_uy.py',
#  '~$Best Results.xlsx',
#  '~$FO_Agottani.docx']

# %% [markdown]
# # Crossover analysis

# %% [markdown]
# # s100_random_tournament_pmx_co_inversion_mutation

# %%
path = 's100_random_tournament_pmx_co_inversion_mutation/s100_random_tournament_pmx_co_inversion_mutation_'
path_results = 's100_random_tournament_pmx_co_inversion_mutation/Bests100_random_tournament_pmx_co_inversion_mutation_'

s100_RTPMXCOIM_0303 = pd.read_excel(path + 'co_p_0.3_mu_p_0.3.xlsx')
s100_RTPMXCOIM_0306 = pd.read_excel(path + 'co_p_0.3_mu_p_0.6.xlsx')
s100_RTPMXCOIM_0308 = pd.read_excel(path + 'co_p_0.3_mu_p_0.8.xlsx')
s100_RTPMXCOIM_0603 = pd.read_excel(path + 'co_p_0.6_mu_p_0.3.xlsx')
s100_RTPMXCOIM_0606 = pd.read_excel(path + 'co_p_0.6_mu_p_0.6.xlsx')
s100_RTPMXCOIM_0608 = pd.read_excel(path + 'co_p_0.6_mu_p_0.8.xlsx')
s100_RTPMXCOIM_0803 = pd.read_excel(path + 'co_p_0.8_mu_p_0.3.xlsx')
s100_RTPMXCOIM_0806 = pd.read_excel(path + 'co_p_0.8_mu_p_0.6.xlsx')
s100_RTPMXCOIM_0808 = pd.read_excel(path + 'co_p_0.8_mu_p_0.8.xlsx')

Bests100_RTPMXCOIM_0303 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.3.xlsx')
Bests100_RTPMXCOIM_0306 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.6.xlsx')
Bests100_RTPMXCOIM_0308 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.8.xlsx')
Bests100_RTPMXCOIM_0603 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.3.xlsx')
Bests100_RTPMXCOIM_0606 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.6.xlsx')
Bests100_RTPMXCOIM_0608 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.8.xlsx')
Bests100_RTPMXCOIM_0803 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.3.xlsx')
Bests100_RTPMXCOIM_0806 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.6.xlsx')
Bests100_RTPMXCOIM_0808 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.8.xlsx')

# %%
def concat_results(df1, df2, df3):
    final_df = pd.concat([df1.loc[:,'best_score_list'],
                          df2.loc[:,'best_score_list'], 
                          df3.loc[:,'best_score_list']], 
                          axis = 1)
    final_df.columns = ['Mutation Probability 0.3', 'Mutation Probability 0.6', 'Mutation Probability 0.8']
    return final_df

# %%
s100_RTPMXCOIM_03 = concat_results(s100_RTPMXCOIM_0303,s100_RTPMXCOIM_0306,s100_RTPMXCOIM_0308)
s100_RTPMXCOIM_06 = concat_results(s100_RTPMXCOIM_0603,s100_RTPMXCOIM_0606,s100_RTPMXCOIM_0608)
s100_RTPMXCOIM_08 = concat_results(s100_RTPMXCOIM_0803,s100_RTPMXCOIM_0806,s100_RTPMXCOIM_0808)

# %%
plt.figure(figsize=(3,6))
sns.set_style("whitegrid")
fig = sns.lineplot(data=s100_RTPMXCOIM_03)
fig.set_title('s100_RTPMXCOIM Crossover Probability 0.3')
fig.set(ylim=(9000, 30000))
# Out:
# [(9000.0, 30000.0)]

# %%
plt.figure(figsize=(3,6))
sns.set_style("whitegrid")
fig = sns.lineplot(data=s100_RTPMXCOIM_06)
fig.set_title('s100_RTPMXCOIM Crossover Probability 0.6')
fig.set(ylim=(9000, 30000))
# Out:
# [(9000.0, 30000.0)]

# %%
fig = sns.lineplot(data=s100_RTPMXCOIM_08)
fig.set_title('s100_RTPMXCOIM Crossover Probability 0.8')
plt.figure(figsize=(3,6))
sns.set_style("whitegrid")
fig.set(ylim=(9000, 30000))
# Out:
# [(9000.0, 30000.0)]

# %%
s100_RTPMXCOIM_0803['best_score_list'].min()
# Out:
# 8845

# %%
route_s100_RTPMXCOIM_0803 = Bests100_RTPMXCOIM_0803['best_population']

# %% [markdown]
# # s100_random_tournament_cycle_co_inversion_mutation

# %%
path = 's100_random_tournament_cycle_co_inversion_mutation/s100_random_tournament_cycle_co_inversion_mutation_'
path_results = 's100_random_tournament_cycle_co_inversion_mutation/Bests100_random_tournament_cycle_co_inversion_mutation_'

s100_RTCYCCOIM_0303 = pd.read_excel(path + 'co_p_0.3_mu_p_0.3.xlsx')
s100_RTCYCCOIM_0306 = pd.read_excel(path + 'co_p_0.3_mu_p_0.6.xlsx')
s100_RTCYCCOIM_0308 = pd.read_excel(path + 'co_p_0.3_mu_p_0.8.xlsx')
s100_RTCYCCOIM_0603 = pd.read_excel(path + 'co_p_0.6_mu_p_0.3.xlsx')
s100_RTCYCCOIM_0606 = pd.read_excel(path + 'co_p_0.6_mu_p_0.6.xlsx')
s100_RTCYCCOIM_0608 = pd.read_excel(path + 'co_p_0.6_mu_p_0.8.xlsx')
s100_RTCYCCOIM_0803 = pd.read_excel(path + 'co_p_0.8_mu_p_0.3.xlsx')
s100_RTCYCCOIM_0806 = pd.read_excel(path + 'co_p_0.8_mu_p_0.6.xlsx')
s100_RTCYCCOIM_0808 = pd.read_excel(path + 'co_p_0.8_mu_p_0.8.xlsx')

Bests100_RTCYCCOIM_0303 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.3.xlsx')
Bests100_RTCYCCOIM_0306 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.6.xlsx')
Bests100_RTCYCCOIM_0308 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.8.xlsx')
Bests100_RTCYCCOIM_0603 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.3.xlsx')
Bests100_RTCYCCOIM_0606 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.6.xlsx')
Bests100_RTCYCCOIM_0608 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.8.xlsx')
Bests100_RTCYCCOIM_0803 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.3.xlsx')
Bests100_RTCYCCOIM_0806 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.6.xlsx')
Bests100_RTCYCCOIM_0808 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.8.xlsx')

# %%
s100_RTCYCCOIM_03 = concat_results(s100_RTCYCCOIM_0303,s100_RTCYCCOIM_0306,s100_RTCYCCOIM_0308)
s100_RTCYCCOIM_06 = concat_results(s100_RTCYCCOIM_0603,s100_RTCYCCOIM_0606,s100_RTCYCCOIM_0608)
s100_RTCYCCOIM_08 = concat_results(s100_RTCYCCOIM_0803,s100_RTCYCCOIM_0806,s100_RTCYCCOIM_0808)

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s100_RTCYCCOIM_03)
fig.set_title('s100_RTCYCCOIM Crossover Probability 0.3')
fig.set(ylim=(9000, 30000))
# Out:
# [(9000.0, 30000.0)]

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s100_RTCYCCOIM_06)
fig.set_title('s100_RTCYCCOIM Crossover Probability 0.6')
fig.set(ylim=(9000, 30000))
# Out:
# [(9000.0, 30000.0)]

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s100_RTCYCCOIM_08)
fig.set_title('s100_RTCYCCOIM Crossover Probability 0.8')
fig.set(ylim=(9000, 30000))
# Out:
# [(9000.0, 30000.0)]

# %%
s100_RTCYCCOIM_0803['best_score_list'].min()
# Out:
# 11176

# %%
route_s100_RTCYCCOIM_0803 = Bests100_RTCYCCOIM_0803['best_population']

# %% [markdown]
# # Mutation Analysis

# %% [markdown]
# # s100_random_tournament_pmx_co_swap_mutation

# %%
path = 's100_random_tournament_pmx_co_swap_mutation/s100_random_tournament_pmx_co_swap_mutation_'
path_results = 's100_random_tournament_pmx_co_swap_mutation/Bests100_random_tournament_pmx_co_swap_mutation_'

s100_RTPMXCOSM_0303 = pd.read_excel(path + 'co_p_0.3_mu_p_0.3.xlsx')
s100_RTPMXCOSM_0306 = pd.read_excel(path + 'co_p_0.3_mu_p_0.6.xlsx')
s100_RTPMXCOSM_0308 = pd.read_excel(path + 'co_p_0.3_mu_p_0.8.xlsx')
s100_RTPMXCOSM_0603 = pd.read_excel(path + 'co_p_0.6_mu_p_0.3.xlsx')
s100_RTPMXCOSM_0606 = pd.read_excel(path + 'co_p_0.6_mu_p_0.6.xlsx')
s100_RTPMXCOSM_0608 = pd.read_excel(path + 'co_p_0.6_mu_p_0.8.xlsx')
s100_RTPMXCOSM_0803 = pd.read_excel(path + 'co_p_0.8_mu_p_0.3.xlsx')
s100_RTPMXCOSM_0806 = pd.read_excel(path + 'co_p_0.8_mu_p_0.6.xlsx')
s100_RTPMXCOSM_0808 = pd.read_excel(path + 'co_p_0.8_mu_p_0.8.xlsx')

Bests100_RTPMXCOSM_0303 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.3.xlsx')
Bests100_RTPMXCOSM_0306 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.6.xlsx')
Bests100_RTPMXCOSM_0308 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.8.xlsx')
Bests100_RTPMXCOSM_0603 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.3.xlsx')
Bests100_RTPMXCOSM_0606 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.6.xlsx')
Bests100_RTPMXCOSM_0608 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.8.xlsx')
Bests100_RTPMXCOSM_0803 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.3.xlsx')
Bests100_RTPMXCOSM_0806 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.6.xlsx')
Bests100_RTPMXCOSM_0808 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.8.xlsx')

# %%
s100_RTPMXCOSM_03 = concat_results(s100_RTPMXCOSM_0303,s100_RTPMXCOSM_0306,s100_RTPMXCOSM_0308)
s100_RTPMXCOSM_06 = concat_results(s100_RTPMXCOSM_0603,s100_RTPMXCOSM_0606,s100_RTPMXCOSM_0608)
s100_RTPMXCOSM_08 = concat_results(s100_RTPMXCOSM_0803,s100_RTPMXCOSM_0806,s100_RTPMXCOSM_0808)

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s100_RTPMXCOSM_03)
fig.set_title('s100_RTPMXCOSM Crossover Probability 0.3')
fig.set(ylim=(9000, 30000))
# Out:
# [(9000.0, 30000.0)]

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s100_RTPMXCOSM_06)
fig.set_title('s100_RTPMXCOSM Crossover Probability 0.6')
fig.set(ylim=(9000, 30000))
# Out:
# [(9000.0, 30000.0)]

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s100_RTPMXCOSM_08)
fig.set_title('s100_RTPMXCOSM Crossover Probability 0.8')
fig.set(ylim=(9000, 30000))
# Out:
# [(9000.0, 30000.0)]

# %%
s100_RTPMXCOSM_0806['best_score_list'].min()
# Out:
# 10307

# %%
route_s100_RTPMXCOSM_0806 = Bests100_RTPMXCOSM_0806['best_population']

# %% [markdown]
# # Initialization Analysis

# %% [markdown]
# # s100_hill_climp_tournament_pmx_co_inversion_mutation

# %%
path = 's100_hill_climp_tournament_pmx_co_inversion_mutation/s100_hill_climp_tournament_pmx_co_inversion_mutation_'
path_results = 's100_hill_climp_tournament_pmx_co_inversion_mutation/Bests100_hill_climp_tournament_pmx_co_inversion_mutation_'

s100_HCTPMXCOIM_0303 = pd.read_excel(path + 'co_p_0.3_mu_p_0.3.xlsx')
s100_HCTPMXCOIM_0306 = pd.read_excel(path + 'co_p_0.3_mu_p_0.6.xlsx')
s100_HCTPMXCOIM_0308 = pd.read_excel(path + 'co_p_0.3_mu_p_0.8.xlsx')
s100_HCTPMXCOIM_0603 = pd.read_excel(path + 'co_p_0.6_mu_p_0.3.xlsx')
s100_HCTPMXCOIM_0606 = pd.read_excel(path + 'co_p_0.6_mu_p_0.6.xlsx')
s100_HCTPMXCOIM_0608 = pd.read_excel(path + 'co_p_0.6_mu_p_0.8.xlsx')
s100_HCTPMXCOIM_0803 = pd.read_excel(path + 'co_p_0.8_mu_p_0.3.xlsx')
s100_HCTPMXCOIM_0806 = pd.read_excel(path + 'co_p_0.8_mu_p_0.6.xlsx')
s100_HCTPMXCOIM_0808 = pd.read_excel(path + 'co_p_0.8_mu_p_0.8.xlsx')

Bests100_HCTPMXCOIM_0303 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.3.xlsx')
Bests100_HCTPMXCOIM_0306 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.6.xlsx')
Bests100_HCTPMXCOIM_0308 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.8.xlsx')
Bests100_HCTPMXCOIM_0603 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.3.xlsx')
Bests100_HCTPMXCOIM_0606 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.6.xlsx')
Bests100_HCTPMXCOIM_0608 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.8.xlsx')
Bests100_HCTPMXCOIM_0803 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.3.xlsx')
Bests100_HCTPMXCOIM_0806 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.6.xlsx')
Bests100_HCTPMXCOIM_0808 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.8.xlsx')

# %%
s100_HCTPMXCOIM_03 = concat_results(s100_HCTPMXCOIM_0303,s100_HCTPMXCOIM_0306,s100_HCTPMXCOIM_0308)
s100_HCTPMXCOIM_06 = concat_results(s100_HCTPMXCOIM_0603,s100_HCTPMXCOIM_0606,s100_HCTPMXCOIM_0608)
s100_HCTPMXCOIM_08 = concat_results(s100_HCTPMXCOIM_0803,s100_HCTPMXCOIM_0806,s100_HCTPMXCOIM_0808)

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s100_HCTPMXCOIM_03)
fig.set_title('s100_HCTPMXCOIM Crossover Probability 0.3')
fig.set(ylim=(9000, 30000))
# Out:
# [(9000.0, 30000.0)]

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s100_HCTPMXCOIM_06)
fig.set_title('s100_HCTPMXCOIM Crossover Probability 0.6')
fig.set(ylim=(9000, 30000))
# Out:
# [(9000.0, 30000.0)]

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s100_HCTPMXCOIM_08)
fig.set_title('s100_HCTPMXCOIM Crossover Probability 0.8')
fig.set(ylim=(9000, 30000))
# Out:
# [(9000.0, 30000.0)]

# %%
s100_HCTPMXCOIM_0806['best_score_list'].min()
# Out:
# 9087

# %%
route_s100_HCTPMXCOIM_0806 = Bests100_HCTPMXCOIM_0806['best_population']

# %% [markdown]
# # s100_sim_annealing_tournament_pmx_co_inversion_mutation

# %%
path = 's100_sim_annealing_tournament_pmx_co_inversion_mutation/s100_sim_annealing_tournament_pmx_co_inversion_mutation_'
path_results = 's100_sim_annealing_tournament_pmx_co_inversion_mutation/Bests100_sim_annealing_tournament_pmx_co_inversion_mutation_'

s100_SATPMXCOIM_0303 = pd.read_excel(path + 'co_p_0.3_mu_p_0.3.xlsx')
s100_SATPMXCOIM_0306 = pd.read_excel(path + 'co_p_0.3_mu_p_0.6.xlsx')
s100_SATPMXCOIM_0308 = pd.read_excel(path + 'co_p_0.3_mu_p_0.8.xlsx')
s100_SATPMXCOIM_0603 = pd.read_excel(path + 'co_p_0.6_mu_p_0.3.xlsx')
s100_SATPMXCOIM_0606 = pd.read_excel(path + 'co_p_0.6_mu_p_0.6.xlsx')
s100_SATPMXCOIM_0608 = pd.read_excel(path + 'co_p_0.6_mu_p_0.8.xlsx')
s100_SATPMXCOIM_0803 = pd.read_excel(path + 'co_p_0.8_mu_p_0.3.xlsx')
s100_SATPMXCOIM_0806 = pd.read_excel(path + 'co_p_0.8_mu_p_0.6.xlsx')
s100_SATPMXCOIM_0808 = pd.read_excel(path + 'co_p_0.8_mu_p_0.8.xlsx')

Bests100_SATPMXCOIM_0303 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.3.xlsx')
Bests100_SATPMXCOIM_0306 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.6.xlsx')
Bests100_SATPMXCOIM_0308 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.8.xlsx')
Bests100_SATPMXCOIM_0603 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.3.xlsx')
Bests100_SATPMXCOIM_0606 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.6.xlsx')
Bests100_SATPMXCOIM_0608 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.8.xlsx')
Bests100_SATPMXCOIM_0803 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.3.xlsx')
Bests100_SATPMXCOIM_0806 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.6.xlsx')
Bests100_SATPMXCOIM_0808 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.8.xlsx')

# %%
s100_SATPMXCOIM_03 = concat_results(s100_SATPMXCOIM_0303,s100_SATPMXCOIM_0306,s100_SATPMXCOIM_0308)
s100_SATPMXCOIM_06 = concat_results(s100_SATPMXCOIM_0603,s100_SATPMXCOIM_0606,s100_SATPMXCOIM_0608)
s100_SATPMXCOIM_08 = concat_results(s100_SATPMXCOIM_0803,s100_SATPMXCOIM_0806,s100_SATPMXCOIM_0808)

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s100_SATPMXCOIM_03)
fig.set_title('s100_SATPMXCOIM Crossover Probability 0.3')
fig.set(ylim=(8500, 30000))
# Out:
# [(8500.0, 30000.0)]

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s100_SATPMXCOIM_06)
fig.set_title('s100_SATPMXCOIM Crossover Probability 0.6')
fig.set(ylim=(8500, 30000))
# Out:
# [(8500.0, 30000.0)]

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s100_SATPMXCOIM_08)
fig.set_title('s100_SATPMXCOIM Crossover Probability 0.8')
fig.set(ylim=(8500, 30000))
# Out:
# [(8500.0, 30000.0)]

# %%
s100_SATPMXCOIM_0803['best_score_list'].min()
# Out:
# 8595

# %%
route_s100_SATPMXCOIM_0803 = Bests100_SATPMXCOIM_0803['best_population']

# %% [markdown]
# # Population Analysis

# %% [markdown]
# # s50_random_tournament_pmx_co_inversion_mutation

# %%
path = 's50_random_tournament_pmx_co_inversion_mutation/s50_random_tournament_pmx_co_inversion_mutation_'
path_results = 's50_random_tournament_pmx_co_inversion_mutation/Bests50_random_tournament_pmx_co_inversion_mutation_'

s50_RTPMXCOIM_0303 = pd.read_excel(path + 'co_p_0.3_mu_p_0.3.xlsx')
s50_RTPMXCOIM_0306 = pd.read_excel(path + 'co_p_0.3_mu_p_0.6.xlsx')
s50_RTPMXCOIM_0308 = pd.read_excel(path + 'co_p_0.3_mu_p_0.8.xlsx')
s50_RTPMXCOIM_0603 = pd.read_excel(path + 'co_p_0.6_mu_p_0.3.xlsx')
s50_RTPMXCOIM_0606 = pd.read_excel(path + 'co_p_0.6_mu_p_0.6.xlsx')
s50_RTPMXCOIM_0608 = pd.read_excel(path + 'co_p_0.6_mu_p_0.8.xlsx')
s50_RTPMXCOIM_0803 = pd.read_excel(path + 'co_p_0.8_mu_p_0.3.xlsx')
s50_RTPMXCOIM_0806 = pd.read_excel(path + 'co_p_0.8_mu_p_0.6.xlsx')
s50_RTPMXCOIM_0808 = pd.read_excel(path + 'co_p_0.8_mu_p_0.8.xlsx')

Bests50_RTPMXCOIM_0303 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.3.xlsx')
Bests50_RTPMXCOIM_0306 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.6.xlsx')
Bests50_RTPMXCOIM_0308 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.8.xlsx')
Bests50_RTPMXCOIM_0603 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.3.xlsx')
Bests50_RTPMXCOIM_0606 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.6.xlsx')
Bests50_RTPMXCOIM_0608 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.8.xlsx')
Bests50_RTPMXCOIM_0803 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.3.xlsx')
Bests50_RTPMXCOIM_0806 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.6.xlsx')
Bests50_RTPMXCOIM_0808 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.8.xlsx')

# %%
s50_RTPMXCOIM_03 = concat_results(s50_RTPMXCOIM_0303,s50_RTPMXCOIM_0306,s50_RTPMXCOIM_0308)
s50_RTPMXCOIM_06 = concat_results(s50_RTPMXCOIM_0603,s50_RTPMXCOIM_0606,s50_RTPMXCOIM_0608)
s50_RTPMXCOIM_08 = concat_results(s50_RTPMXCOIM_0803,s50_RTPMXCOIM_0806,s50_RTPMXCOIM_0808)

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s50_RTPMXCOIM_03)
fig.set_title('s50_RTPMXCOIM Crossover Probability 0.3')
fig.set(ylim=(8500, 30000))
# Out:
# [(8500.0, 30000.0)]

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s50_RTPMXCOIM_06)
fig.set_title('s50_RTPMXCOIM Crossover Probability 0.6')
fig.set(ylim=(8500, 30000))
# Out:
# [(8500.0, 30000.0)]

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s50_RTPMXCOIM_08)
fig.set_title('s50_RTPMXCOIM Crossover Probability 0.8')
fig.set(ylim=(8500, 30000))
# Out:
# [(8500.0, 30000.0)]

# %%
s50_RTPMXCOIM_0803['best_score_list'].min()
# Out:
# 8982

# %%
route_s50_RTPMXCOIM_0803 = Bests50_RTPMXCOIM_0803['best_population']

# %% [markdown]
# # s100_random_tournament_pmx_co_inversion_mutation_EF

# %%
path = 's100_random_tournament_pmx_co_inversion_mutation_EF/s100_random_tournament_pmx_co_inversion_mutation_EF_'
path_results = 's100_random_tournament_pmx_co_inversion_mutation_EF/Bests100_random_tournament_pmx_co_inversion_mutation_EF_'

s100_RTPMXCOIMEF_0303 = pd.read_excel(path + 'co_p_0.3_mu_p_0.3.xlsx')
s100_RTPMXCOIMEF_0306 = pd.read_excel(path + 'co_p_0.3_mu_p_0.6.xlsx')
s100_RTPMXCOIMEF_0308 = pd.read_excel(path + 'co_p_0.3_mu_p_0.8.xlsx')
s100_RTPMXCOIMEF_0603 = pd.read_excel(path + 'co_p_0.6_mu_p_0.3.xlsx')
s100_RTPMXCOIMEF_0606 = pd.read_excel(path + 'co_p_0.6_mu_p_0.6.xlsx')
s100_RTPMXCOIMEF_0608 = pd.read_excel(path + 'co_p_0.6_mu_p_0.8.xlsx')
s100_RTPMXCOIMEF_0803 = pd.read_excel(path + 'co_p_0.8_mu_p_0.3.xlsx')
s100_RTPMXCOIMEF_0806 = pd.read_excel(path + 'co_p_0.8_mu_p_0.6.xlsx')
s100_RTPMXCOIMEF_0808 = pd.read_excel(path + 'co_p_0.8_mu_p_0.8.xlsx')

Bests100_RTPMXCOIMEF_0303 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.3.xlsx')
Bests100_RTPMXCOIMEF_0306 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.6.xlsx')
Bests100_RTPMXCOIMEF_0308 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.8.xlsx')
Bests100_RTPMXCOIMEF_0603 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.3.xlsx')
Bests100_RTPMXCOIMEF_0606 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.6.xlsx')
Bests100_RTPMXCOIMEF_0608 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.8.xlsx')
Bests100_RTPMXCOIMEF_0803 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.3.xlsx')
Bests100_RTPMXCOIMEF_0806 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.6.xlsx')
Bests100_RTPMXCOIMEF_0808 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.8.xlsx')

# %%
s100_RTPMXCOIMEF_03 = concat_results(s100_RTPMXCOIMEF_0303,s100_RTPMXCOIMEF_0306,s100_RTPMXCOIMEF_0308)
s100_RTPMXCOIMEF_06 = concat_results(s100_RTPMXCOIMEF_0603,s100_RTPMXCOIMEF_0606,s100_RTPMXCOIMEF_0608)
s100_RTPMXCOIMEF_08 = concat_results(s100_RTPMXCOIMEF_0803,s100_RTPMXCOIMEF_0806,s100_RTPMXCOIMEF_0808)

# %%
plt.figure(figsize=(3,6))
sns.set_style("whitegrid")
fig = sns.lineplot(data=s100_RTPMXCOIMEF_03)
fig.set_title('s100_RTPMXCOIMEF Crossover Probability 0.3')
fig.set(ylim=(9000, 30000))
# Out:
# [(9000.0, 30000.0)]

# %%
plt.figure(figsize=(3,6))
sns.set_style("whitegrid")
fig = sns.lineplot(data=s100_RTPMXCOIMEF_06)
fig.set_title('s100_RTPMXCOIM Crossover Probability 0.6')
fig.set(ylim=(9000, 35000))
# Out:
# [(9000.0, 35000.0)]

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s100_RTPMXCOIMEF_08)
fig.set_title('s100_RTPMXCOIM Crossover Probability 0.8')
sns.set_style("whitegrid")
fig.set(ylim=(9000, 30000))
# Out:
# [(9000.0, 30000.0)]

# %%
s100_RTPMXCOIMEF_0803['best_score_list'].min()
# Out:
# 9633

# %%
route_s100_RTPMXCOIMEF_0803 = Bests100_RTPMXCOIMEF_0803['best_population']

# %% [markdown]
# # BEST RESULTS

# %%
# s100_random_tournament_pmx_co_inversion_mutation 
# Best: route_s100_RTPMXCOIM_0803
# 8719

# s100_random_tournament_cycle_co_inversion_mutation
# Best: route_s100_RTCYCCOIM_0803
# 11176
    
# s100_random_tournament_pmx_co_swap_mutation
# Best: route_s100_RTPMXCOSM_0806
# 10307

# s100_hill_climp_tournament_pmx_co_inversion_mutation
# route_s100_HCTPMXCOIM_0806
# 9087

# s100_sim_annealing_tournament_pmx_co_inversion_mutation
# Best: route_s100_SATPMXCOIM_0803
# 8595

# s50_random_tournament_pmx_co_inversion_mutation
# Best: route_s50_RTPMXCOIM_0803
# 8982

# s100_random_tournament_pmx_co_inversion_mutation_EF

# %%
class Coor:
    def __init__(self, index, x, y):
        self.index = index
        self.x = x
        self.y = y
        
def from_file(file_path):
    with open(file_path, 'r') as f:
        line = f.readline()
        output = []
        while line:
            line = line.replace('\n', '').split(' ')
            line = [float(x) if '.' in x else x for x in line]  # convert decimals
            line = [int(x) if type(x) is str and x.isdigit() else x for x in line]  # convert integers
            if type(line[0]) is int:
                output.append(Coor(line[0] - 1, line[2], line[1]))
            line = f.readline()
    return output

# %%
data=from_file('data/berlin52.txt')

# %%
def plot_graph(data, sequence, plt):
    data_x = [_.x for _ in data]
    data_y = [_.y for _ in data]
    plt.scatter(data_x, data_y, c='#ff0000')
    for i, num in enumerate(sequence):
        if i is 0:
            plt.plot([data[sequence[0]].x, data[sequence[-1]].x], [data[sequence[0]].y, data[sequence[-1]].y])
        else:
            plt.plot([data[num].x, data[sequence[i - 1]].x], [data[num].y, data[sequence[i - 1]].y])

# %%
plt.figure(figsize=(12,6))
plt.title('Berlin_52 best sequence')
plot_graph(data,route_s100_SATPMXCOIM_0803.to_list(),plt)

# %% [markdown]
# # Uruguay Data Set

# %%
path = 's100_random_tournament_pmx_co_inversion_mutation_uy/s100_random_tournament_pmx_co_inversion_mutation_uy_'
path_results = 's100_random_tournament_pmx_co_inversion_mutation_uy/Bests100_random_tournament_pmx_co_inversion_mutation_uy_'

s100_RTPMXCOIMuy_0303 = pd.read_excel(path + 'co_p_0.3_mu_p_0.3.xlsx')
s100_RTPMXCOIMuy_0306 = pd.read_excel(path + 'co_p_0.3_mu_p_0.6.xlsx')
s100_RTPMXCOIMuy_0308 = pd.read_excel(path + 'co_p_0.3_mu_p_0.8.xlsx')
s100_RTPMXCOIMuy_0603 = pd.read_excel(path + 'co_p_0.6_mu_p_0.3.xlsx')
s100_RTPMXCOIMuy_0606 = pd.read_excel(path + 'co_p_0.6_mu_p_0.6.xlsx')
s100_RTPMXCOIMuy_0608 = pd.read_excel(path + 'co_p_0.6_mu_p_0.8.xlsx')
s100_RTPMXCOIMuy_0803 = pd.read_excel(path + 'co_p_0.8_mu_p_0.3.xlsx')
s100_RTPMXCOIMuy_0806 = pd.read_excel(path + 'co_p_0.8_mu_p_0.6.xlsx')
s100_RTPMXCOIMuy_0808 = pd.read_excel(path + 'co_p_0.8_mu_p_0.8.xlsx')

Bests100_RTPMXCOIMuy_0303 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.3.xlsx')
Bests100_RTPMXCOIMuy_0306 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.6.xlsx')
Bests100_RTPMXCOIMuy_0308 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.8.xlsx')
Bests100_RTPMXCOIMuy_0603 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.3.xlsx')
Bests100_RTPMXCOIMuy_0606 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.6.xlsx')
Bests100_RTPMXCOIMuy_0608 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.8.xlsx')
Bests100_RTPMXCOIMuy_0803 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.3.xlsx')
Bests100_RTPMXCOIMuy_0806 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.6.xlsx')
Bests100_RTPMXCOIMuy_0808 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.8.xlsx')

# %%
s100_RTPMXCOIMuy_03 = concat_results(s100_RTPMXCOIMuy_0303,s100_RTPMXCOIMuy_0306,s100_RTPMXCOIMuy_0308)
s100_RTPMXCOIMuy_06 = concat_results(s100_RTPMXCOIMuy_0603,s100_RTPMXCOIMuy_0606,s100_RTPMXCOIMuy_0608)
s100_RTPMXCOIMuy_08 = concat_results(s100_RTPMXCOIMuy_0803,s100_RTPMXCOIMuy_0806,s100_RTPMXCOIMuy_0808)

# %%
plt.figure(figsize=(3,6))
sns.set_style("whitegrid")
fig = sns.lineplot(data=s100_RTPMXCOIMuy_03)
fig.set_title('s100_RTPMXCOIM uy_734 Crossover Probability 0.3')
# Out:
# Text(0.5, 1.0, 's100_RTPMXCOIM uy_734 Crossover Probability 0.3')

# %%
plt.figure(figsize=(3,6))
sns.set_style("whitegrid")
fig = sns.lineplot(data=s100_RTPMXCOIMuy_06)
fig.set_title('s100_RTPMXCOIM Crossover Probability 0.6')
# Out:
# Text(0.5, 1.0, 's100_RTPMXCOIM Crossover Probability 0.6')

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s100_RTPMXCOIMuy_08)
fig.set_title('s100_RTPMXCOIM Crossover Probability 0.8 UY')
sns.set_style("whitegrid")

# %%
s100_RTPMXCOIMuy_0803['best_score_list'].min()
# Out:
# 1086472

# %%
route_s100_RTPMXCOIMuy_0803 = Bests100_RTPMXCOIMuy_0803['best_population']

# %%
route_s100_RTPMXCOIMuy_0803
# Out:
# 0      313
# 1      437
# 2      721
# 3      347
# 4      297
#       ...
# 729    550
# 730    245
# 731    517
# 732    632
# 733    236
# Name: best_population, Length: 734, dtype: int64

# %%
data_2=from_file('data/uy734.txt')
plt.figure(figsize=(12,6))
plt.clf()
plt.title('Uy_734 best sequence')
plot_graph(data_2,route_s100_RTPMXCOIMuy_0803.to_list(),plt)

# %% [markdown]
# # PR Data Set

# %%
path = 's100_random_tournament_pmx_co_inversion_mutation_pr/s100_random_tournament_pmx_co_inversion_mutation_pr_'
path_results = 's100_random_tournament_pmx_co_inversion_mutation_pr/Bests100_random_tournament_pmx_co_inversion_mutation_pr_'

s100_RTPMXCOIMpr_0303 = pd.read_excel(path + 'co_p_0.3_mu_p_0.3.xlsx')
s100_RTPMXCOIMpr_0306 = pd.read_excel(path + 'co_p_0.3_mu_p_0.6.xlsx')
s100_RTPMXCOIMpr_0308 = pd.read_excel(path + 'co_p_0.3_mu_p_0.8.xlsx')
s100_RTPMXCOIMpr_0603 = pd.read_excel(path + 'co_p_0.6_mu_p_0.3.xlsx')
s100_RTPMXCOIMpr_0606 = pd.read_excel(path + 'co_p_0.6_mu_p_0.6.xlsx')
s100_RTPMXCOIMpr_0608 = pd.read_excel(path + 'co_p_0.6_mu_p_0.8.xlsx')
s100_RTPMXCOIMpr_0803 = pd.read_excel(path + 'co_p_0.8_mu_p_0.3.xlsx')
s100_RTPMXCOIMpr_0806 = pd.read_excel(path + 'co_p_0.8_mu_p_0.6.xlsx')
s100_RTPMXCOIMpr_0808 = pd.read_excel(path + 'co_p_0.8_mu_p_0.8.xlsx')

Bests100_RTPMXCOIMpr_0303 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.3.xlsx')
Bests100_RTPMXCOIMpr_0306 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.6.xlsx')
Bests100_RTPMXCOIMpr_0308 = pd.read_excel(path_results + 'co_p_0.3_mu_p_0.8.xlsx')
Bests100_RTPMXCOIMpr_0603 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.3.xlsx')
Bests100_RTPMXCOIMpr_0606 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.6.xlsx')
Bests100_RTPMXCOIMpr_0608 = pd.read_excel(path_results + 'co_p_0.6_mu_p_0.8.xlsx')
Bests100_RTPMXCOIMpr_0803 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.3.xlsx')
Bests100_RTPMXCOIMpr_0806 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.6.xlsx')
Bests100_RTPMXCOIMpr_0808 = pd.read_excel(path_results + 'co_p_0.8_mu_p_0.8.xlsx')

# %%
s100_RTPMXCOIMpr_03 = concat_results(s100_RTPMXCOIMpr_0303,s100_RTPMXCOIMpr_0306,s100_RTPMXCOIMpr_0308)
s100_RTPMXCOIMpr_06 = concat_results(s100_RTPMXCOIMpr_0603,s100_RTPMXCOIMpr_0606,s100_RTPMXCOIMpr_0608)
s100_RTPMXCOIMpr_08 = concat_results(s100_RTPMXCOIMpr_0803,s100_RTPMXCOIMpr_0806,s100_RTPMXCOIMpr_0808)

# %%
plt.figure(figsize=(3,6))
sns.set_style("whitegrid")
fig = sns.lineplot(data=s100_RTPMXCOIMpr_03)
fig.set_title('s100_RTPMXCOIM Crossover Probability 0.3')
# Out:
# Text(0.5, 1.0, 's100_RTPMXCOIM Crossover Probability 0.3')

# %%
plt.figure(figsize=(3,6))
sns.set_style("whitegrid")
fig = sns.lineplot(data=s100_RTPMXCOIMpr_06)
fig.set_title('s100_RTPMXCOIM Crossover Probability 0.6')
# Out:
# Text(0.5, 1.0, 's100_RTPMXCOIM Crossover Probability 0.6')

# %%
plt.figure(figsize=(3,6))
fig = sns.lineplot(data=s100_RTPMXCOIMpr_08)
fig.set_title('s100_RTPMXCOIM Crossover Probability 0.8 PR')
sns.set_style("whitegrid")

# %%
s100_RTPMXCOIMpr_0806['best_score_list'].min()
# Out:
# 12262714

# %%
route_s100_RTPMXCOIMpr_0806 = Bests100_RTPMXCOIMpr_0806['best_population']

# %%
route_s100_RTPMXCOIMpr_0803
# Out:
# 0      313
# 1      437
# 2      721
# 3      347
# 4      297
#       ...
# 729    550
# 730    245
# 731    517
# 732    632
# 733    236
# Name: best_population, Length: 734, dtype: int64

# %%
data_3=from_file('data/pr2392.txt')
plt.figure(figsize=(12,6))
plt.clf()
plt.title('pr_2392 best sequence')
plot_graph(data_3,route_s100_RTPMXCOIMpr_0806.to_list(),plt)
